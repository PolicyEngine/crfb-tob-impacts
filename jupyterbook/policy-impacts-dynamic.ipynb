# %% [markdown]
# # Dynamic Policy Impacts Analysis
#
# This notebook calculates both static and dynamic budgetary impacts for all reform options.
# Dynamic scoring incorporates CBO labor supply response elasticities to estimate behavioral effects.
#
# **Note**: This notebook generates the data files used in the revenue impacts analysis. Run this first to update the static and dynamic impact estimates.

# %%
# Import necessary libraries
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
from policyengine_us import Microsimulation
from policyengine_core.reforms import Reform
from reforms import REFORMS
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Setup: CBO Labor Response Parameters
#
# Define the CBO labor supply elasticities used for dynamic scoring:

# %%
# CBO labor supply elasticities
# Note: Using simplified parameters to avoid recursion issues
# Full CBO elasticities can cause circular dependencies in benefit calculations
CBO_LABOR_PARAMS = {
    "gov.simulation.labor_supply_responses.elasticities.income": {
        "2024-01-01.2100-12-31": -0.05
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1": {
        "2024-01-01.2100-12-31": 0.31
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.2": {
        "2024-01-01.2100-12-31": 0.28
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.3": {
        "2024-01-01.2100-12-31": 0.27
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.4": {
        "2024-01-01.2100-12-31": 0.27
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.5": {
        "2024-01-01.2100-12-31": 0.25
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.6": {
        "2024-01-01.2100-12-31": 0.25
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.7": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.8": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.9": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.10": {
        "2024-01-01.2100-12-31": 0.22
    },
    "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.secondary": {
        "2024-01-01.2100-12-31": 0.27
    },
    # Substitution elasticities commented out due to recursion issues
    # These create circular dependencies with SNAP and other benefit calculations
    # "gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1": {
    #     "2024-01-01.2100-12-31": 0.31
    # },
    # ... (other substitution elasticities)
}

print("CBO labor supply elasticities configured")
print(f"Income elasticity: {CBO_LABOR_PARAMS['gov.simulation.labor_supply_responses.elasticities.income']['2024-01-01.2100-12-31']}")
print(f"Primary earner substitution (decile 1): {CBO_LABOR_PARAMS['gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.primary.1']['2024-01-01.2100-12-31']}")
print(f"Secondary earner substitution: {CBO_LABOR_PARAMS['gov.simulation.labor_supply_responses.elasticities.substitution.by_position_and_decile.secondary']['2024-01-01.2100-12-31']}")

# %% [markdown]
# ## Helper Functions

# %%
def create_dynamic_reform(base_reform_dict, labor_params=CBO_LABOR_PARAMS):
    """
    Combine a base reform with CBO labor supply elasticities.
    
    Args:
        base_reform_dict: Dictionary of reform parameters  
        labor_params: Dictionary of labor supply elasticity parameters
    
    Returns:
        Reform object with combined parameters
    """
    # Combine dictionaries (both use DOT notation for date ranges)
    combined_dict = {**base_reform_dict, **labor_params}
    
    return Reform.from_dict(combined_dict, country_id="us")


def get_reform_dict(reform_func):
    """
    Extract the underlying parameter dictionary from a reform function.
    
    This works by importing the helper functions from reforms.py that return
    the raw dictionaries before they're wrapped in Reform objects.
    """
    # Import the helper functions that return dicts
    from reforms import (
        eliminate_ss_taxation, tax_85_percent_ss, tax_100_percent_ss,
        extend_senior_deduction, add_ss_tax_credit, eliminate_senior_deduction,
        enable_employer_payroll_tax
    )
    
    # Map each reform function to its underlying dict-returning function(s)
    # This is based on the structure in reforms.py
    reform_func_name = reform_func.__name__
    
    if reform_func_name == "get_option1_reform":
        return eliminate_ss_taxation()
    elif reform_func_name == "get_option2_reform":
        return tax_85_percent_ss()
    elif reform_func_name == "get_option3_reform":
        return {**tax_85_percent_ss(), **extend_senior_deduction()}
    elif reform_func_name == "get_option4_reform":
        return {**tax_85_percent_ss(), **add_ss_tax_credit(500), **eliminate_senior_deduction()}
    elif reform_func_name == "get_option5_reform":
        return {**eliminate_ss_taxation(), **enable_employer_payroll_tax(1.0)}
    elif reform_func_name == "get_option6_reform":
        # Option 6 is more complex with phase-in schedules
        return {
            "gov.contrib.crfb.tax_employer_payroll_tax.in_effect": {
                "2026-01-01.2100-12-31": True
            },
            "gov.contrib.crfb.tax_employer_payroll_tax.percentage": {
                "2026-01-01.2026-12-31": 0.1307,
                "2027-01-01.2027-12-31": 0.2614,
                "2028-01-01.2028-12-31": 0.3922,
                "2029-01-01.2029-12-31": 0.5229,
                "2030-01-01.2030-12-31": 0.6536,
                "2031-01-01.2031-12-31": 0.7843,
                "2032-01-01.2032-12-31": 0.9150,
                "2033-01-01.2100-12-31": 1.0
            },
            "gov.irs.social_security.taxability.rate.base": {
                "2029-01-01.2029-12-31": 0.45,
                "2030-01-01.2030-12-31": 0.40,
                "2031-01-01.2031-12-31": 0.35,
                "2032-01-01.2032-12-31": 0.30,
                "2033-01-01.2033-12-31": 0.25,
                "2034-01-01.2034-12-31": 0.20,
                "2035-01-01.2035-12-31": 0.15,
                "2036-01-01.2036-12-31": 0.10,
                "2037-01-01.2037-12-31": 0.05,
                "2038-01-01.2100-12-31": 0
            },
            "gov.irs.social_security.taxability.rate.additional": {
                "2029-01-01.2029-12-31": 0.80,
                "2030-01-01.2030-12-31": 0.75,
                "2031-01-01.2031-12-31": 0.70,
                "2032-01-01.2032-12-31": 0.65,
                "2033-01-01.2033-12-31": 0.60,
                "2034-01-01.2034-12-31": 0.55,
                "2035-01-01.2035-12-31": 0.50,
                "2036-01-01.2036-12-31": 0.45,
                "2037-01-01.2037-12-31": 0.40,
                "2038-01-01.2038-12-31": 0.35,
                "2039-01-01.2039-12-31": 0.30,
                "2040-01-01.2040-12-31": 0.25,
                "2041-01-01.2041-12-31": 0.20,
                "2042-01-01.2042-12-31": 0.15,
                "2043-01-01.2043-12-31": 0.10,
                "2044-01-01.2044-12-31": 0.05,
                "2045-01-01.2100-12-31": 0
            }
        }
    elif reform_func_name == "get_option7_reform":
        return eliminate_senior_deduction()
    elif reform_func_name == "get_option8_reform":
        return tax_100_percent_ss()
    else:
        raise ValueError(f"Unknown reform function: {reform_func_name}")


def calculate_revenue_impact(reform, year, baseline_income_tax):
    """
    Calculate revenue impact for a given reform and year.
    
    Args:
        reform: Reform object (can be static or dynamic)
        year: Year to calculate impact for
        baseline_income_tax: Pre-computed baseline income tax array
    
    Returns:
        Revenue impact in dollars (positive = revenue gain, negative = revenue loss)
    """
    # Create reformed simulation
    reform_sim = Microsimulation(reform=reform)
    
    # Calculate reformed income tax
    reform_income_tax = reform_sim.calculate("income_tax", map_to="household", period=year)
    
    # JCT convention: reformed - baseline (positive = more revenue)
    revenue_impact = reform_income_tax.sum() - baseline_income_tax.sum()
    
    return revenue_impact


def compute_baselines(years):
    """Pre-compute baselines for all years to avoid redundant calculations.
    
    Args:
        years: List of years to compute baselines for
    
    Returns:
        Dictionary mapping years to baseline income tax arrays
    """
    print("Pre-computing baselines for all years...")
    baselines = {}
    
    for year in years:
        print(f"  Computing baseline for {year}...")
        baseline = Microsimulation()
        baseline_income_tax = baseline.calculate("income_tax", map_to="household", period=year)
        baselines[year] = baseline_income_tax
    
    print("Baseline computation complete!\n")
    return baselines


print("Helper functions defined")
# Out:
# Helper functions defined

# %% [markdown]
# ## Static Impact Calculation
#
# Calculate static budgetary impacts (without behavioral responses) for all reforms across 2026-2035.
# This recalculates the baseline estimates with the latest PolicyEngine US updates.

# %%
# Years to analyze
YEARS = list(range(2026, 2036))

# Pre-compute baselines for all years
baselines = compute_baselines(YEARS)

# Storage for results
static_results = []

# Create data directory if it doesn't exist
import os
os.makedirs('../data', exist_ok=True)

print("\n" + "="*80)
print("STATIC IMPACT CALCULATIONS")
print("="*80)
print(f"Analyzing {len(REFORMS)} reforms across {len(YEARS)} years = {len(REFORMS) * len(YEARS)} calculations\n")

for reform_id, reform_config in tqdm(REFORMS.items(), desc="Reforms"):
    reform_name = reform_config['name']
    reform_func = reform_config['func']
    
    print(f"\nProcessing {reform_id}: {reform_name}")
    
    try:
        # Get the static reform (already works with the existing Reform objects from reforms.py)
        static_reform = reform_func()
        
        for year in tqdm(YEARS, desc=f"  Years ({reform_id})", leave=False):
            print(f"  Calculating {year}...", end=' ')
            
            impact = calculate_revenue_impact(static_reform, year, baselines[year])
            
            static_results.append({
                'reform_id': reform_id,
                'reform_name': reform_name,
                'year': year,
                'revenue_impact': impact,
                'scoring_type': 'static'
            })
            
            print(f"${impact/1e9:.2f}B")
        
        # Save checkpoint after each reform completes
        checkpoint_df = pd.DataFrame(static_results)
        checkpoint_df.to_csv('../data/policy_impacts_static_checkpoint.csv', index=False)
        print(f"  ✓ Checkpoint saved ({len(static_results)} records so far)")
        
    except Exception as e:
        print(f"  ✗ ERROR processing {reform_id}: {type(e).__name__}: {e}")
        print(f"  Continuing with next reform...")
        import traceback
        traceback.print_exc()

# Convert to DataFrame
static_df = pd.DataFrame(static_results)

print("\n" + "="*80)
print("STATIC IMPACTS SUMMARY")
print("="*80)

if len(static_df) > 0:
    # Show 10-year totals
    static_totals = static_df.groupby(['reform_id', 'reform_name'])['revenue_impact'].sum() / 1e9
    print("\n10-Year Static Impacts (2026-2035, Billions):")
    for reform_id, total in static_totals.items():
        print(f"  {reform_id[0]}: ${total:,.1f}B")
    
    print(f"\nTotal records: {len(static_df)}")
else:
    print("⚠ No static results calculated")
# Out:
# Pre-computing baselines for all years...
#   Computing baseline for 2026...
#   Computing baseline for 2027...
#   Computing baseline for 2028...
#   Computing baseline for 2029...
#   Computing baseline for 2030...
#   Computing baseline for 2031...
#   Computing baseline for 2032...
#   Computing baseline for 2033...
#   Computing baseline for 2034...
#   Computing baseline for 2035...
# Baseline computation complete!
#
#
# ================================================================================
# STATIC IMPACT CALCULATIONS
# ================================================================================
# Analyzing 8 reforms across 10 years = 80 calculations
# Reforms:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing option1: Full Repeal of Social Security Benefits Taxation
#   Calculating 2026...
# Reforms:   0%|          | 0/8 [00:06<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/reforms/reform.py:150, in Reform.from_dict.<locals>.reform.apply(self)
#     149 try:
# --> 150     period = period_(period)
#     151     parameter = parameter.update(
#     152         period=period, value=value
#     153     )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/periods/helpers.py:159, in period(value)
#     158 if ":" not in value:
# --> 159     raise_error(value)
#     161 components = value.split(":")
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/periods/helpers.py:139, in period.<locals>.raise_error(value)
#     130 message = os.linesep.join(
#     131     [
#     132         "Expected a period (eg. '2017', '2017-01', '2017-01-01', ...); got: '{}'.".format(
#    (...)
#     137     ]
#     138 )
# --> 139 raise ValueError(message)
#
# ValueError: Expected a period (eg. '2017', '2017-01', '2017-01-01', ...); got: '2026-01-01.2100-12-31'.
# Learn more about legal period formats in OpenFisca:
# <https://openfisca.org/doc/coding-the-legislation/35_periods.html#periods-in-simulations>.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 27
#      24 for year in tqdm(YEARS, desc=f"  Years ({reform_id})", leave=False):
#      25     print(f"  Calculating {year}...", end=' ')
# ---> 27     impact = calculate_revenue_impact(static_reform, year, baselines[year])
#      29     static_results.append({
#      30         'reform_id': reform_id,
#      31         'reform_name': reform_name,
#    (...)
#      34         'scoring_type': 'static'
#      35     })
#      37     print(f"${impact/1e9:.2f}B")
#
# Cell In[7], line 115, in calculate_revenue_impact(reform, year, baseline_income_tax)
#     103 """
#     104 Calculate revenue impact for a given reform and year.
#     105
#    (...)
#     112     Revenue impact in dollars (positive = revenue gain, negative = revenue loss)
#     113 """
#     114 # Create reformed simulation
# --> 115 reform_sim = Microsimulation(reform=reform)
#     117 # Calculate reformed income tax
#     118 reform_income_tax = reform_sim.calculate("income_tax", map_to="household", period=year)
#
# File ~/policyengine-us/policyengine_us/system.py:220, in Microsimulation.__init__(self, *args, **kwargs)
#     213 if (
#     214     dataset is not None
#     215     and isinstance(dataset, str)
#     216     and "cps_2023" in dataset
#     217 ):
#     218     self.default_input_period = 2023
# --> 220 super().__init__(*args, **kwargs)
#     222 reform = create_structural_reforms_from_parameters(
#     223     self.tax_benefit_system.parameters, start_instant
#     224 )
#     225 if reform is not None:
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/simulations/simulation.py:108, in Simulation.__init__(self, tax_benefit_system, populations, situation, dataset, reform, trace, default_input_period, default_calculation_period)
#     106         tax_benefit_system = self.default_tax_benefit_system_instance
#     107     else:
# --> 108         tax_benefit_system = self.default_tax_benefit_system(
#     109             reform=reform
#     110         )
#     111     self.tax_benefit_system = tax_benefit_system
#     113 self.reform = reform
#
# File ~/policyengine-us/policyengine_us/system.py:80, in CountryTaxBenefitSystem.__init__(self, reform, start_instant)
#      78 self.add_abolition_parameters()
#      79 if reform:
# ---> 80     self.apply_reform_set(reform)
#      81 self.parameters = set_irs_uprating_parameter(self.parameters)
#      82 self.parameters = homogenize_parameter_structures(
#      83     self.parameters, self.variables
#      84 )
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/taxbenefitsystems/tax_benefit_system.py:156, in TaxBenefitSystem.apply_reform_set(self, reform)
#     153     from policyengine_core.reforms import Reform
#     155     reform = Reform.from_dict(reform)
# --> 156 reform.apply(self)
#
# File ~/anaconda3/envs/pe/lib/python3.10/site-packages/policyengine_core/reforms/reform.py:159, in Reform.from_dict.<locals>.reform.apply(self)
#     157     start = instant_(start)
#     158     stop = instant_(stop)
# --> 159     parameter.update(
#     160         start=start, stop=stop, value=value
#     161     )
#     162 else:
#     163     parameter = parameter.update(
#     164         period=period, value=value
#     165     )
#
# AttributeError: 'ParameterNode' object has no attribute 'update'

# %% [markdown]
# ## Dynamic Impact Calculation
#
# Calculate dynamic budgetary impacts incorporating CBO labor supply elasticities.
# This captures behavioral responses to tax changes.

# %%
# Storage for dynamic results
dynamic_results = []

# Create data directory if it doesn't exist
import os
os.makedirs('../data', exist_ok=True)

print("\n" + "="*80)
print("DYNAMIC IMPACT CALCULATIONS")
print("="*80)
print(f"Analyzing {len(REFORMS)} reforms across {len(YEARS)} years = {len(REFORMS) * len(YEARS)} calculations\n")

for reform_id, reform_config in tqdm(REFORMS.items(), desc="Reforms"):
    reform_name = reform_config['name']
    reform_func = reform_config['func']
    
    print(f"\nProcessing {reform_id}: {reform_name}")
    
    # Skip Option 6 for dynamic scoring (too complex)
    if reform_id == "option6":
        print("  ⚠ Skipping Option 6 - complex phase-in not compatible with dynamic scoring")
        continue
    
    try:
        # Get the reform dict and combine with labor elasticities
        reform_dict = get_reform_dict(reform_func)
        dynamic_reform = create_dynamic_reform(reform_dict, CBO_LABOR_PARAMS)
        
        for year in tqdm(YEARS, desc=f"  Years ({reform_id})", leave=False):
            print(f"  Calculating {year}...", end=' ')
            
            impact = calculate_revenue_impact(dynamic_reform, year, baselines[year])
            
            dynamic_results.append({
                'reform_id': reform_id,
                'reform_name': reform_name,
                'year': year,
                'revenue_impact': impact,
                'scoring_type': 'dynamic'
            })
            
            print(f"${impact/1e9:.2f}B")
        
        # Save checkpoint after each reform completes
        checkpoint_df = pd.DataFrame(dynamic_results)
        checkpoint_df.to_csv('../data/policy_impacts_dynamic_checkpoint.csv', index=False)
        print(f"  ✓ Checkpoint saved ({len(dynamic_results)} records so far)")
        
    except Exception as e:
        print(f"  ✗ ERROR processing {reform_id}: {type(e).__name__}: {e}")
        print(f"  Continuing with next reform...")
        import traceback
        traceback.print_exc()

# Convert to DataFrame
dynamic_df = pd.DataFrame(dynamic_results)

print("\n" + "="*80)
print("DYNAMIC IMPACTS SUMMARY")
print("="*80)

if len(dynamic_df) > 0:
    # Show 10-year totals
    dynamic_totals = dynamic_df.groupby(['reform_id', 'reform_name'])['revenue_impact'].sum() / 1e9
    print("\n10-Year Dynamic Impacts (2026-2035, Billions):")
    for reform_id, total in dynamic_totals.items():
        print(f"  {reform_id[0]}: ${total:,.1f}B")
    
    print(f"\nTotal records: {len(dynamic_df)}")
else:
    print("⚠ No dynamic results calculated")
# Out:
# ================================================================================
# DYNAMIC IMPACT CALCULATIONS
# ================================================================================
# Analyzing 8 reforms across 10 years = 80 calculations
# Reforms:   0%|          | 0/8 [00:00<?, ?it/s]
# Processing option1: Full Repeal of Social Security Benefits Taxation
#   Calculating 2026...
#   ✗ ERROR processing option1: Exception: RecursionError while calculating snap for period 2026-01. The full computation stack is:
#   - household_net_income 2026, baseline_lsr_measurement
#   - household_benefits 2026, baseline_lsr_measurement
#   - snap 2026, baseline_lsr_measurement
#   - snap 2026-01, baseline_lsr_measurement
#   Continuing with next reform...
# Traceback (most recent call last):
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\snap.py", line 18, in formula
#     takes_up = spm_unit("takes_up_snap_if_eligible", period)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 686, in _calculate
#     values = self._calculate(variable_name, period.this_year)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 630, in _calculate
#     cached_array = holder.get_array(period, self.branch_name)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\holders\holder.py", line 111, in get_array
#     if value is None and period in self.get_known_periods():
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\holders\holder.py", line 175, in get_known_periods
#     return list(self._memory_storage.get_known_periods()) + list(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\data_storage\in_memory_storage.py", line 65, in get_known_periods
#     return list(
#            ^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\data_storage\in_memory_storage.py", line 66, in <lambda>
#     map(lambda x: periods.period(x.split(":")[1]), self._arrays.keys())
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\periods\helpers.py", line 153, in period
#     period = parse_simple_period(value)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\periods\helpers.py", line 99, in parse_simple_period
#     date = datetime.datetime.strptime(value, "%Y")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Roaming\uv\python\cpython-3.12.10-windows-x86_64-none\Lib\_strptime.py", line 653, in _strptime_datetime
#     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Roaming\uv\python\cpython-3.12.10-windows-x86_64-none\Lib\_strptime.py", line 405, in _strptime
#     if (_getlang() != locale_time.lang or
#         ^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Roaming\uv\python\cpython-3.12.10-windows-x86_64-none\Lib\_strptime.py", line 29, in _getlang
#     return locale.getlocale(locale.LC_TIME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Roaming\uv\python\cpython-3.12.10-windows-x86_64-none\Lib\locale.py", line 598, in getlocale
#     return _parse_localename(localename)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Roaming\uv\python\cpython-3.12.10-windows-x86_64-none\Lib\locale.py", line 478, in _parse_localename
#     code = normalize(localename)
#            ^^^^^^^^^^^^^^^^^^^^^
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\dtsax\AppData\Local\Temp\ipykernel_26872\1883425329.py", line 32, in <module>
#     impact = calculate_revenue_impact(dynamic_reform, year, baselines[year])
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\AppData\Local\Temp\ipykernel_26872\1691823402.py", line 81, in calculate_revenue_impact
#     reform_income_tax = reform_sim.calculate("income_tax", map_to="household", period=year)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\income_tax.py", line 18, in formula
#     added_components = add(
#                        ^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 188, in for_each_variable
#     values = entity(variable, period, options=options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\income_tax_before_refundable_credits.py", line 18, in formula
#     added_components = add(
#                        ^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 188, in for_each_variable
#     values = entity(variable, period, options=options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\tax\federal_income\before_credits\income_tax_main_rates.py", line 14, in formula
#     full_taxable_income = tax_unit("taxable_income", period)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\taxable_income.py", line 12, in formula
#     agi = tax_unit("adjusted_gross_income", period)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\adjusted_gross_income\adjusted_gross_income.py", line 13, in formula
#     gross_income = add(tax_unit, period, ["irs_gross_income"])
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 191, in for_each_variable
#     entity.members(variable, period, options=options)
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\adjusted_gross_income\irs_gross_income\irs_gross_income.py", line 19, in formula
#     total += not_dependent * max_(0, add(person, period, [source]))
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 188, in for_each_variable
#     values = entity(variable, period, options=options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\adjusted_gross_income\irs_gross_income\irs_employment_income.py", line 13, in formula
#     employment_income = person("employment_income", period)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\employment_income_behavioral_response.py", line 12, in formula
#     lsr = person("labor_supply_behavioral_response", period)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\labor_supply_behavioral_response.py", line 51, in formula
#     response = add(
#                ^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 188, in for_each_variable
#     values = entity(variable, period, options=options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\income_elasticity_lsr.py", line 22, in formula
#     income_change = person("relative_income_change", period)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\relative_income_change.py", line 23, in formula
#     net_income = measurement_person.household(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\projectors\projector.py", line 33, in __call__
#     result = self.reference_entity(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 681, in _calculate
#     values = self.calculate_add(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 67, in calculate_add
#     values = super().calculate_add(variable_name, period, map_to)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 846, in calculate_add
#     result = sum(
#              ^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 847, in <genexpr>
#     self.calculate(variable_name, sub_period)
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\snap.py", line 25, in formula
#     value = add(
#             ^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 232, in add
#     return for_each_variable(
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py", line 188, in for_each_variable
#     values = entity(variable, period, options=options)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 699, in _calculate
#     self.calculate(
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\eligibility\is_snap_eligible.py", line 16, in formula
#     net = spm_unit("meets_snap_net_income_test", period)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\eligibility\meets_snap_net_income_test.py", line 19, in formula
#     net_income_fpg = spm_unit("snap_net_income_fpg_ratio", period)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1003, in _run_formula
#     array = formula(population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\income\snap_net_income_fpg_ratio.py", line 15, in formula
#     income = spm_unit("snap_net_income", period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1003, in _run_formula
#     array = formula(population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\income\snap_net_income.py", line 15, in formula
#     deductions = spm_unit("snap_deductions", period)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\income\deductions\snap_standard_deduction.py", line 18, in formula
#     unit = spm_unit("snap_unit_size", period)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\group_population.py", line 38, in __call__
#     return super().__call__(variable_name, period, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 686, in _calculate
#     values = self._calculate(variable_name, period.this_year)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\snap_unit.py", line 13, in formula
#     ineligible_student = person("is_snap_ineligible_student", period)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 1005, in _run_formula
#     array = formula(population, period, parameters_at)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-us\policyengine_us\variables\gov\usda\snap\eligibility\student\is_snap_ineligible_student.py", line 20, in formula
#     hours_worked = person("weekly_hours_worked", period)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\populations\population.py", line 140, in __call__
#     return self.simulation.calculate(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 485, in calculate
#     result = self._calculate(variable_name, period)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 715, in _calculate
#     array = self._run_formula(variable, population, period)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py", line 940, in _run_formula
#     values = values + self.calculate(
#                       ^^^^^^^^^^^^^^^
#   File "C:\Users\dtsax\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py", line 54, in calculate
#     values = super().calculate(variable_name, period, map_to, decode_enums)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
#     713 try:
#     714     self._check_for_cycle(variable.name, period)
# --> 715     array = self._run_formula(variable, population, period)
#     717     # If no result, use the default value and cache it
#     718     if array is None:
#     719         # Check if the variable has a previously defined value
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1005, in Simulation._run_formula(self, variable, population, period)
#    1003     array = formula(population, period)
#    1004 else:
# -> 1005     array = formula(population, period, parameters_at)
#    1007 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\adjusted_gross_income\irs_gross_income\irs_gross_income.py:19, in irs_gross_income.formula(person, period, parameters)
#      16 not_dependent = ~person("is_tax_unit_dependent", period)
#      17 for source in sources:
#      18     # Add positive values only - losses are deducted later.
# ---> 19     total += not_dependent * max_(0, add(person, period, [source]))
#      20 return total
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py:232, in add(entity, period, variables, options)
#     212 def add(
#     213     entity: Population,
#     214     period: Period,
#     215     variables: List[str],
#     216     options: List[str] = None,
#     217 ):
#     218     """Sums a list of variables.
#     219
#     220     Args:
#    (...)
#     230         ArrayLike: The result of the operation.
#     231     """
# --> 232     return for_each_variable(
#     233         entity, period, variables, agg_func="add", options=options
#     234     )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\commons\formulas.py:188, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     186 variable_entity = entity.entity.get_variable(variable).entity
#     187 if variable_entity.key == entity.entity.key:
# --> 188     values = entity(variable, period, options=options)
#     189 elif variable_entity.is_person:
#     190     values = group_agg_func(
#     191         entity.members(variable, period, options=options)
#     192     )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\populations\population.py:140, in Population.__call__(self, variable_name, period, options)
#     136     return self.simulation.calculate_divide(
#     137         variable_name, period, **calculate_kwargs
#     138     )
#     139 else:
# --> 140     return self.simulation.calculate(
#     141         variable_name, period, **calculate_kwargs
#     142     )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:485, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     482 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     484 try:
# --> 485     result = self._calculate(variable_name, period)
#     486     if isinstance(result, EnumArray) and decode_enums:
#     487         result = result.decode_to_str()
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:715, in Simulation._calculate(self, variable_name, period)
#     713 try:
#     714     self._check_for_cycle(variable.name, period)
# --> 715     array = self._run_formula(variable, population, period)
#     717     # If no result, use the default value and cache it
#     718     if array is None:
#     719         # Check if the variable has a previously defined value
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1005, in Simulation._run_formula(self, variable, population, period)
#    1003     array = formula(population, period)
#    1004 else:
# -> 1005     array = formula(population, period, parameters_at)
#    1007 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\irs\income\taxable_income\adjusted_gross_income\irs_gross_income\irs_employment_income.py:13, in irs_employment_income.formula(person, period, parameters)
#      12 def formula(person, period, parameters):
# ---> 13     employment_income = person("employment_income", period)
#      14     pre_tax_contributions = person("pre_tax_contributions", period)
#      15     return max_(0, employment_income - pre_tax_contributions)
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\populations\population.py:140, in Population.__call__(self, variable_name, period, options)
#     136     return self.simulation.calculate_divide(
#     137         variable_name, period, **calculate_kwargs
#     138     )
#     139 else:
# --> 140     return self.simulation.calculate(
#     141         variable_name, period, **calculate_kwargs
#     142     )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:485, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     482 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     484 try:
# --> 485     result = self._calculate(variable_name, period)
#     486     if isinstance(result, EnumArray) and decode_enums:
#     487         result = result.decode_to_str()
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:715, in Simulation._calculate(self, variable_name, period)
#     713 try:
#     714     self._check_for_cycle(variable.name, period)
# --> 715     array = self._run_formula(variable, population, period)
#     717     # If no result, use the default value and cache it
#     718     if array is None:
#     719         # Check if the variable has a previously defined value
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:940, in Simulation._run_formula(self, variable, population, period)
#     938 for added_variable in adds_list:
#     939     if added_variable in self.tax_benefit_system.variables:
# --> 940         values = values + self.calculate(
#     941             added_variable, period, map_to=variable.entity.key
#     942         )
#     943     else:
#     944         try:
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:485, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     482 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     484 try:
# --> 485     result = self._calculate(variable_name, period)
#     486     if isinstance(result, EnumArray) and decode_enums:
#     487         result = result.decode_to_str()
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:715, in Simulation._calculate(self, variable_name, period)
#     713 try:
#     714     self._check_for_cycle(variable.name, period)
# --> 715     array = self._run_formula(variable, population, period)
#     717     # If no result, use the default value and cache it
#     718     if array is None:
#     719         # Check if the variable has a previously defined value
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1005, in Simulation._run_formula(self, variable, population, period)
#    1003     array = formula(population, period)
#    1004 else:
# -> 1005     array = formula(population, period, parameters_at)
#    1007 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\employment_income_behavioral_response.py:12, in employment_income_behavioral_response.formula(person, period, parameters)
#      11 def formula(person, period, parameters):
# ---> 12     lsr = person("labor_supply_behavioral_response", period)
#      13     raw_earnings = add(
#      14         person,
#      15         period,
#    (...)
#      19         ],
#      20     )
#      21     earnings = max_(raw_earnings, 0)
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\populations\population.py:140, in Population.__call__(self, variable_name, period, options)
#     136     return self.simulation.calculate_divide(
#     137         variable_name, period, **calculate_kwargs
#     138     )
#     139 else:
# --> 140     return self.simulation.calculate(
#     141         variable_name, period, **calculate_kwargs
#     142     )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:485, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     482 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     484 try:
# --> 485     result = self._calculate(variable_name, period)
#     486     if isinstance(result, EnumArray) and decode_enums:
#     487         result = result.decode_to_str()
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:715, in Simulation._calculate(self, variable_name, period)
#     713 try:
#     714     self._check_for_cycle(variable.name, period)
# --> 715     array = self._run_formula(variable, population, period)
#     717     # If no result, use the default value and cache it
#     718     if array is None:
#     719         # Check if the variable has a previously defined value
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1005, in Simulation._run_formula(self, variable, population, period)
#    1003     array = formula(population, period)
#    1004 else:
# -> 1005     array = formula(population, period, parameters_at)
#    1007 return array
#
# File ~\PolicyEngine\policyengine-us\policyengine_us\variables\gov\simulation\labor_supply_response\labor_supply_behavioral_response.py:19, in labor_supply_behavioral_response.formula(person, period, parameters)
#      16 if p.elasticities.income == 0 and p.elasticities.substitution.all == 0:
#      17     return 0
# ---> 19 measurement_branch = simulation.get_branch(
#      20     "lsr_measurement", clone_system=True
#      21 )  # A branch without LSRs
#      22 baseline_branch = simulation.get_branch("baseline").get_branch(
#      23     "baseline_lsr_measurement", clone_system=True
#      24 )  # Already created by default
#      25 baseline_branch.tax_benefit_system.parameters.simulation = (
#      26     measurement_branch.tax_benefit_system.parameters.simulation
#      27 )
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1317, in Simulation.get_branch(self, name, clone_system)
#    1315 if name in self.branches:
#    1316     return self.branches[name]
# -> 1317 branch = self.clone(clone_tax_benefit_system=clone_system)
#    1318 self.branches[name] = branch
#    1319 branch.branch_name = name
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\simulations\simulation.py:1293, in Simulation.clone(self, debug, trace, clone_tax_benefit_system)
#    1289     setattr(
#    1290         new, entity.key, population
#    1291     )  # create shortcut simulation.household (for instance)
#    1292 if clone_tax_benefit_system:
# -> 1293     new.tax_benefit_system = self.tax_benefit_system.clone()
#    1294 else:
#    1295     new.tax_benefit_system = self.tax_benefit_system
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\taxbenefitsystems\tax_benefit_system.py:683, in TaxBenefitSystem.clone(self)
#     673     if key not in (
#     674         "parameters",
#     675         "_parameters_at_instant_cache",
#    (...)
#     679         "group_entities",
#     680     ):
#     681         new_dict[key] = value
# --> 683 new_dict["parameters"] = self.parameters.clone()
#     684 new_dict["_parameters_at_instant_cache"] = {}
#     685 new_dict["variables"] = {
#     686     variable_name: variable.clone()
#     687     for variable_name, variable in self.variables.items()
#     688 }
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\parameters\parameter_node.py:223, in ParameterNode.clone(self)
#     219 clone.__dict__ = self.__dict__.copy()
#     221 clone.metadata = copy.deepcopy(self.metadata)
#     222 clone.children = {
# --> 223     key: child.clone() for key, child in self.children.items()
#     224 }
#     225 for child_key, child in clone.children.items():
#     226     setattr(clone, child_key, child)
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\parameters\parameter_node.py:223, in ParameterNode.clone(self)
#     219 clone.__dict__ = self.__dict__.copy()
#     221 clone.metadata = copy.deepcopy(self.metadata)
#     222 clone.children = {
# --> 223     key: child.clone() for key, child in self.children.items()
#     224 }
#     225 for child_key, child in clone.children.items():
#     226     setattr(clone, child_key, child)
#
#     [... skipping similar frames: ParameterNode.clone at line 223 (2 times)]
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\parameters\parameter_node.py:223, in ParameterNode.clone(self)
#     219 clone.__dict__ = self.__dict__.copy()
#     221 clone.metadata = copy.deepcopy(self.metadata)
#     222 clone.children = {
# --> 223     key: child.clone() for key, child in self.children.items()
#     224 }
#     225 for child_key, child in clone.children.items():
#     226     setattr(clone, child_key, child)
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\parameters\parameter.py:135, in Parameter.clone(self)
#     131 clone.__dict__ = self.__dict__.copy()
#     133 clone.metadata = copy.deepcopy(self.metadata)
#     134 clone.values_list = [
# --> 135     parameter_at_instant.clone()
#     136     for parameter_at_instant in self.values_list
#     137 ]
#     138 return clone
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\parameters\parameter_at_instant.py:81, in ParameterAtInstant.clone(self)
#      80 def clone(self) -> "ParameterAtInstant":
# ---> 81     clone = commons.empty_clone(self)
#      82     clone.__dict__ = self.__dict__.copy()
#      83     clone.metadata = copy.deepcopy(self.metadata)
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\commons\misc.py:41, in empty_clone(original)
#      33 new: T
#      35 Dummy = type(
#      36     "Dummy",
#      37     (original.__class__,),
#      38     {"__init__": lambda self: None},
#      39 )
# ---> 41 new = Dummy()
#      42 new.__class__ = original.__class__
#      43 return new
#
# File ~\PolicyEngine\policyengine-core\policyengine_core\commons\misc.py:38, in empty_clone.<locals>.<lambda>(self)
#      32 Dummy: object
#      33 new: T
#      35 Dummy = type(
#      36     "Dummy",
#      37     (original.__class__,),
# ---> 38     {"__init__": lambda self: None},
#      39 )
#      41 new = Dummy()
#      42 new.__class__ = original.__class__
#
# KeyboardInterrupt:

# %% [markdown]
# ## Comparison: Dynamic vs Static
#
# Calculate the difference between dynamic and static scores to show the behavioral feedback effects.

# %%
# Merge static and dynamic results
print("\n" + "="*80)
print("BEHAVIORAL FEEDBACK EFFECTS")
print("="*80)

if len(static_df) == 0:
    print("⚠ No static results to compare")
elif len(dynamic_df) == 0:
    print("⚠ No dynamic results to compare")
else:
    comparison_df = pd.merge(
        static_df[['reform_id', 'reform_name', 'year', 'revenue_impact']].rename(columns={'revenue_impact': 'static_impact'}),
        dynamic_df[['reform_id', 'reform_name', 'year', 'revenue_impact']].rename(columns={'revenue_impact': 'dynamic_impact'}),
        on=['reform_id', 'reform_name', 'year'],
        how='outer'  # Use outer join to keep all results even if one side is missing
    )

    # Calculate difference (dynamic - static)
    # Positive difference = behavioral responses increase revenue relative to static
    # Negative difference = behavioral responses decrease revenue relative to static
    comparison_df['dynamic_feedback'] = comparison_df['dynamic_impact'] - comparison_df['static_impact']

    # Calculate percentage difference
    comparison_df['feedback_pct'] = (comparison_df['dynamic_feedback'] / comparison_df['static_impact'].abs()) * 100

    # Show 10-year feedback effects (only for reforms with both static and dynamic)
    complete_reforms = comparison_df.dropna(subset=['static_impact', 'dynamic_impact'])
    
    if len(complete_reforms) > 0:
        feedback_summary = complete_reforms.groupby(['reform_id', 'reform_name']).agg({
            'static_impact': 'sum',
            'dynamic_impact': 'sum',
            'dynamic_feedback': 'sum'
        }) / 1e9

        feedback_summary['feedback_pct'] = (feedback_summary['dynamic_feedback'] / feedback_summary['static_impact'].abs()) * 100

        print("\n10-Year Comparison (2026-2035, Billions):")
        print("-" * 80)
        for (reform_id, reform_name), row in feedback_summary.iterrows():
            print(f"\n{reform_id}: {reform_name}")
            print(f"  Static impact:     ${row['static_impact']:>8,.1f}B")
            print(f"  Dynamic impact:    ${row['dynamic_impact']:>8,.1f}B")
            print(f"  Feedback effect:   ${row['dynamic_feedback']:>8,.1f}B ({row['feedback_pct']:+.1f}%)")

        print(f"\n✓ Comparison complete for {len(feedback_summary)} reforms")
    else:
        print("\n⚠ No reforms have both static and dynamic results to compare")
        comparison_df = pd.DataFrame()  # Empty dataframe

    comparison_df.head()

# %% [markdown]
# ## Export Results
#
# Save all results to CSV files for use in other analyses and visualizations.

# %%
import os

# Create data directory if it doesn't exist
os.makedirs('../data', exist_ok=True)

print("\n" + "="*80)
print("EXPORTING RESULTS")
print("="*80)

# Export static impacts (this replaces the old policy_impacts.csv)
if len(static_df) > 0:
    static_df.to_csv('../data/policy_impacts_static.csv', index=False)
    print("✓ Exported static impacts to: data/policy_impacts_static.csv")
    print(f"  ({len(static_df)} records)")
    
    # Also export a legacy version for backward compatibility
    static_df.to_csv('../data/policy_impacts.csv', index=False)
    print("✓ Exported static impacts (legacy) to: data/policy_impacts.csv")
else:
    print("⚠ No static impacts to export")

# Export dynamic impacts
if len(dynamic_df) > 0:
    dynamic_df.to_csv('../data/policy_impacts_dynamic.csv', index=False)
    print("✓ Exported dynamic impacts to: data/policy_impacts_dynamic.csv")
    print(f"  ({len(dynamic_df)} records)")
else:
    print("⚠ No dynamic impacts to export")

# Export comparison data
if 'comparison_df' in locals() and len(comparison_df) > 0:
    comparison_df.to_csv('../data/policy_impacts_comparison.csv', index=False)
    print("✓ Exported comparison data to: data/policy_impacts_comparison.csv")
    print(f"  ({len(comparison_df)} records)")
    
    # Export summary statistics
    if 'feedback_summary' in locals() and len(feedback_summary) > 0:
        summary_stats = pd.DataFrame({
            'reform_id': feedback_summary.index.get_level_values(0),
            'reform_name': feedback_summary.index.get_level_values(1),
            'static_10yr_billions': feedback_summary['static_impact'].values,
            'dynamic_10yr_billions': feedback_summary['dynamic_impact'].values,
            'feedback_billions': feedback_summary['dynamic_feedback'].values,
            'feedback_percent': feedback_summary['feedback_pct'].values
        })
        summary_stats.to_csv('../data/policy_impacts_summary.csv', index=False)
        print("✓ Exported summary statistics to: data/policy_impacts_summary.csv")
        print(f"  ({len(summary_stats)} reforms)")
else:
    print("⚠ No comparison data to export")

# Clean up checkpoint files if everything completed successfully
if len(static_df) > 0 and len(dynamic_df) > 0:
    if os.path.exists('../data/policy_impacts_static_checkpoint.csv'):
        os.remove('../data/policy_impacts_static_checkpoint.csv')
        print("\n✓ Removed static checkpoint file (all complete)")
    if os.path.exists('../data/policy_impacts_dynamic_checkpoint.csv'):
        os.remove('../data/policy_impacts_dynamic_checkpoint.csv')
        print("✓ Removed dynamic checkpoint file (all complete)")

print("\n" + "="*80)
print("EXPORT SUMMARY")
print("="*80)
print(f"Static reforms processed: {static_df['reform_id'].nunique() if len(static_df) > 0 else 0}")
print(f"Dynamic reforms processed: {dynamic_df['reform_id'].nunique() if len(dynamic_df) > 0 else 0}")
print(f"Years analyzed: {YEARS[0]}-{YEARS[-1]}")
print("\nAll exports complete!")
